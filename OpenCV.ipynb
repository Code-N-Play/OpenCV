# %% [markdown]
# <a href="https://colab.research.google.com/github/Code-N-Play/OpenCV/blob/main/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/imges/img2.jpeg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/imges/img1.png")
resize_img = cv2.resize(img, (200,300))       # first is width and second one is height
cv2_imshow(resize_img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x300>
